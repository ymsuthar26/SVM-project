# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("circle data.xlsx")

# %%
df
# Out:
#          col1      col2  target
# 0    1.040125 -0.095805       0
# 1   -0.500879 -0.791838       0
# 2    0.335667 -0.821072       0
# 3   -0.320325  0.208066       1
# 4   -0.783112  0.809822       0
# ..        ...       ...     ...
# 495  0.367492  0.144546       1
# 496 -0.154622  1.030954       0
# 497  0.139123  0.411886       1
# 498  0.145806  0.257334       1
# 499 -0.467937 -1.034042       0
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(data=df,x='col1',y='col2',c=df['target'])
# Out:
# <Axes: xlabel='col1', ylabel='col2'>

# %%
sns.pairplot(data=df)

# %%
x=df.drop('target',axis=1)
y=df['target']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.49      0.39        43
#            1       0.37      0.23      0.28        57
#
#     accuracy                           0.34       100
#    macro avg       0.35      0.36      0.34       100
# weighted avg       0.35      0.34      0.33       100

# %%
from sklearn.svm import SVC

# %%
model_svc=SVC()

# %%
model_svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=model_svc.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        43
#            1       1.00      1.00      1.00        57
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
